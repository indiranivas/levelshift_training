# %%
# %pip install pdfminer.six
# Out:
# ...
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ----------- ---------------------------- 1.8/6.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.7/6.6 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 12.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------------------------------- ------ 2.9/3.5 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 12.9 MB/s  0:00:00
# ...
#
#    ---------- ----------------------------- 1/4 [cffi]
#    -------------------- ------------------- 2/4 [cryptography]
#    ------------------------------ --------- 3/4 [pdfminer.six]
#    ------------------------------ --------- 3/4 [pdfminer.six]
#    ---------------------------------------- 4/4 [pdfminer.six]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# ...

# %%
# %pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pypdf2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pysqlite3
# Out:
# ...
#    ---------------------------------------- 0.0/903.9 kB ? eta -:--:--
#    ---------------------------------------- 903.9/903.9 kB 11.9 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
